# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns

whale_path = Path("./Resources/whale_returns.csv")

whale_data = pd.read_csv(whale_path, index_col = 'Date', parse_dates = True,infer_datetime_format = True)

# %%
# Count nulls
whale_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_data = whale_data.dropna()
whale_data.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %%
whale_data = whale_data.sort_index()
whale_data
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652
# ...                                 ...                     ...
# 2019-04-25                    -0.005153                0.004848
# 2019-04-26                     0.012355                0.010434
# 2019-04-29                     0.006251                0.005223
# 2019-04-30                    -0.000259               -0.003702
# 2019-05-01                    -0.007936               -0.007833
#
# [1059 rows x 4 columns]

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns

algo_path = Path("./Resources/algo_returns.csv")
algo_data = pd.read_csv(algo_path, index_col = 'Date', parse_dates = True,infer_datetime_format = True)

# %%
# Count nulls
algo_data.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_data = algo_data.dropna()
algo_data.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %%
algo_data = algo_data.sort_index()
algo_data
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761
# ...              ...       ...
# 2019-04-25  0.000682 -0.007247
# 2019-04-26  0.002981  0.005256
# 2019-04-29  0.005208  0.002829
# 2019-04-30 -0.002944 -0.001570
# 2019-05-01  0.000094 -0.007358
#
# [1235 rows x 2 columns]

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P TSX 60 Closing Prices
sp_tsx_path = Path("./Resources/sp_tsx_history.csv")
sp_tsx_data = pd.read_csv(sp_tsx_path, index_col = 'Date', parse_dates = True,infer_datetime_format = True)

# %%
# Check Data Types
sp_tsx_data.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp_tsx_data["Close"] = sp_tsx_data["Close"].str.replace("$", "")
sp_tsx_data["Close"] = sp_tsx_data["Close"].str.replace(",", "")

sp_tsx_data["Close"] = sp_tsx_data["Close"].astype("float")
sp_tsx_data["Close"].dtypes
# Out:
# C:\Users\xuxuz\AppData\Local\Temp\ipykernel_6872\174484468.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   sp_tsx_data["Close"] = sp_tsx_data["Close"].str.replace("$", "")
# dtype('float64')

# %%
# Calculate Daily Returns
sp_tsx_daily_return = sp_tsx_data.pct_change()

sp_tsx_daily_return
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# ...              ...
# 2019-12-20  0.003188
# 2019-12-23  0.000600
# 2019-12-24  0.003003
# 2019-12-27 -0.000695
# 2019-12-30 -0.004057
#
# [1818 rows x 1 columns]

# %%
# Drop nulls
sp_tsx_daily_return = sp_tsx_daily_return.dropna()
sp_tsx_daily_return.isnull().sum()
# Out:
# Close    0
# dtype: int64

# %%
# Rename `Close` Column to be specific to this portfolio.

sp_tsx_daily_return = sp_tsx_daily_return.rename(columns = {'Close':'S&P TSX'})

sp_tsx_daily_return.head()
# Out:
#              S&P TSX
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709

# %%
sp_tsx_daily_return = sp_tsx_daily_return.sort_index()
sp_tsx_daily_return
# Out:
#              S&P TSX
# Date
# 2012-10-02  0.001701
# 2012-10-03 -0.002563
# 2012-10-04  0.007137
# 2012-10-05 -0.002305
# 2012-10-09 -0.011709
# ...              ...
# 2019-12-20  0.003188
# 2019-12-23  0.000600
# 2019-12-24  0.003003
# 2019-12-27 -0.000695
# 2019-12-30 -0.004057
#
# [1817 rows x 1 columns]

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns 
# for each portfolio's returns.

combined = pd.concat([whale_data,algo_data,sp_tsx_daily_return],axis='columns',join = 'inner')

combined
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# ...                                 ...                     ...       ...
# 2019-04-25                    -0.005153                0.004848  0.000682
# 2019-04-26                     0.012355                0.010434  0.002981
# 2019-04-29                     0.006251                0.005223  0.005208
# 2019-04-30                    -0.000259               -0.003702 -0.002944
# 2019-05-01                    -0.007936               -0.007833  0.000094
#
#               Algo 2   S&P TSX
# Date
# 2015-03-03 -0.000949 -0.008530
# 2015-03-04  0.002416 -0.003371
# 2015-03-05  0.004323  0.001344
# 2015-03-06 -0.011460 -0.009972
# 2015-03-09  0.001303 -0.006555
# ...              ...       ...
# 2019-04-25 -0.007247 -0.000628
# 2019-04-26  0.005256  0.002254
# 2019-04-29  0.002829 -0.000788
# 2019-04-30 -0.001570 -0.001183
# 2019-05-01 -0.007358 -0.004703
#
# [1029 rows x 7 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios

combined.plot(figsize=(20,10),title='Daily Return of All Portfolios')
# Out:
# <AxesSubplot:title={'center':'Daily Return of All Portfolios'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios

cumulative_return = (1 + combined).cumprod()-1

# Plot cumulative returns

cumulative_return.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk

combined.plot.box(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
# Calculate  the daily standard deviation of S&P 500

combined_std = combined.std()
combined_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007828
# PAULSON & CO.INC.              0.006982
# TIGER GLOBAL MANAGEMENT LLC    0.010883
# BERKSHIRE HATHAWAY INC         0.012826
# Algo 1                         0.007589
# Algo 2                         0.008326
# S&P TSX                        0.007034
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Determine which portfolios are riskier than the S&P 500

combined_std.plot(kind = 'bar')

print('Only PAULSON & CO.INC. is less riskier than the S&P 500, the other portfolios are all riskier than the S&P 500' )
# Out:
# Only PAULSON & CO.INC. is less riskier than the S&P 500, the other portfolios are all riskier than the S&P 500

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)

combined_annual_std = np.sqrt(252)*combined_std

combined_annual_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# Algo 2                         0.132177
# S&P TSX                        0.111664
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window

combined_rolling = combined.rolling(window=21).std()

# Plot the rolling standard deviation

combined_rolling.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation

correlation = combined.corr()
correlation

# Display the correlation matrix

sns.heatmap(correlation,vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Choose portfolio 'SOROS FUND MANAGEMENT LLC', calculate and plot the 60-day rolling beta 
# between that portfolio and the S&P TSX 60.

# Calculate covariance of a single portfolio

soros_rolling_60days_cov = combined['SOROS FUND MANAGEMENT LLC'].rolling(window=60).cov(combined['S&P TSX'])

# Calculate variance of S&P 500

sp_rolling_60days_var = combined['S&P TSX'].rolling(window=60).var()

# Computing beta

beta_rolling_60days = soros_rolling_60days_cov/sp_rolling_60days_var

# Plot beta trend

beta_rolling_60days.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window

combined_ewm = combined.ewm(halflife=21).std()
combined_ewm
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                   0.002472            0.005814
# 2015-03-05                   0.002677            0.004968
# 2015-03-06                   0.005349            0.004615
# 2015-03-09                   0.004638            0.004471
# ...                               ...                 ...
# 2019-04-25                   0.006819            0.006342
# 2019-04-26                   0.006819            0.006448
# 2019-04-29                   0.006708            0.006357
# 2019-04-30                   0.006617            0.006270
# 2019-05-01                   0.006636            0.006175
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                     0.001441                0.007624  0.004700
# 2015-03-05                     0.002478                0.007020  0.004162
# 2015-03-06                     0.004665                0.009387  0.003419
# 2015-03-09                     0.005496                0.008066  0.002999
# ...                                 ...                     ...       ...
# 2019-04-25                     0.014811                0.010830  0.006526
# 2019-04-26                     0.014764                0.010763  0.006433
# 2019-04-29                     0.014575                0.010601  0.006378
# 2019-04-30                     0.014336                0.010481  0.006310
# 2019-05-01                     0.014166                0.010460  0.006208
#
#               Algo 2   S&P TSX
# Date
# 2015-03-03       NaN       NaN
# 2015-03-04  0.002380  0.003648
# 2015-03-05  0.002662  0.004936
# 2015-03-06  0.007166  0.005205
# 2015-03-09  0.006290  0.004517
# ...              ...       ...
# 2019-04-25  0.007500  0.004700
# 2019-04-26  0.007418  0.004628
# 2019-04-29  0.007304  0.004564
# 2019-04-30  0.007200  0.004507
# 2019-05-01  0.007238  0.004546
#
# [1029 rows x 7 columns]

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios

combined_annual_sharpe = combined.mean()*252/combined_annual_std
combined_annual_sharpe
# Out:
# SOROS FUND MANAGEMENT LLC      0.286709
# PAULSON & CO.INC.             -0.547594
# TIGER GLOBAL MANAGEMENT LLC   -0.144455
# BERKSHIRE HATHAWAY INC         0.467045
# Algo 1                         1.491514
# Algo 2                         0.396817
# S&P TSX                        0.195550
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot

combined_annual_sharpe.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# - Algorithm 1 and Algorithm 2 Vs. S&P 500: the Sharpe Ratio is much higher than S&P 500, meaning the potential return to risk for algorithmic strategies outperform the market (S&P 500)
#
# - Algorithm 1 outperforms all the whales fortfolios
#
# - Algorithm 2 outperforms all the whales fortfolios except BERKSHIRE HATHAWAY INCBERKSHIRE HATHAWAY INC.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock

apple_path = Path("./Resources/AAPL.csv")

apple_data = pd.read_csv(apple_path, index_col = 'Date', parse_dates = True,infer_datetime_format = True)

apple_data
# Out:
#             Close
# Date
# 2012-10-01  23.55
# 2012-10-02  23.62
# 2012-10-03  23.98
# 2012-10-04  23.81
# 2012-10-05  23.31
# ...           ...
# 2019-12-23  71.00
# 2019-12-24  71.07
# 2019-12-26  72.48
# 2019-12-27  72.45
# 2019-12-30  72.88
#
# [1823 rows x 1 columns]

# %%
apple_data.isnull().sum()
apple_data = apple_data.sort_index()
apple_data
# Out:
#             Close
# Date
# 2012-10-01  23.55
# 2012-10-02  23.62
# 2012-10-03  23.98
# 2012-10-04  23.81
# 2012-10-05  23.31
# ...           ...
# 2019-12-23  71.00
# 2019-12-24  71.07
# 2019-12-26  72.48
# 2019-12-27  72.45
# 2019-12-30  72.88
#
# [1823 rows x 1 columns]

# %%
# Reading data from 2nd stock

google_path = Path("./Resources/GOOG.csv")

google_data = pd.read_csv(google_path, index_col = 'Date', parse_dates = True,infer_datetime_format = True)

google_data
# Out:
#             Close
# Date
# 2014-03-27  27.85
# 2014-03-28  27.92
# 2014-03-31  27.77
# 2014-04-01  28.28
# 2014-04-02  28.27
# ...           ...
# 2019-12-23  67.44
# 2019-12-24  67.18
# 2019-12-26  68.02
# 2019-12-27  67.59
# 2019-12-30  66.81
#
# [1451 rows x 1 columns]

# %%
google_data.isnull().sum()
google_data = google_data.sort_index()
google_data
# Out:
#             Close
# Date
# 2014-03-27  27.85
# 2014-03-28  27.92
# 2014-03-31  27.77
# 2014-04-01  28.28
# 2014-04-02  28.27
# ...           ...
# 2019-12-23  67.44
# 2019-12-24  67.18
# 2019-12-26  68.02
# 2019-12-27  67.59
# 2019-12-30  66.81
#
# [1451 rows x 1 columns]

# %%
# Reading data from 3rd stock

tesla_path = Path("./Resources/TSLA.csv")

tesla_data = pd.read_csv(tesla_path, index_col = 'Date', parse_dates = True, infer_datetime_format = True)

tesla_data
# Out:
#             Close
# Date
# 2012-10-01   1.94
# 2012-10-02   1.99
# 2012-10-03   1.95
# 2012-10-04   1.96
# 2012-10-05   1.93
# ...           ...
# 2019-12-23  27.95
# 2019-12-24  28.35
# 2019-12-26  28.73
# 2019-12-27  28.69
# 2019-12-30  27.65
#
# [1823 rows x 1 columns]

# %%
tesla_data.isnull().sum()
tesla_data = tesla_data.sort_index()
tesla_data
# Out:
#             Close
# Date
# 2012-10-01   1.94
# 2012-10-02   1.99
# 2012-10-03   1.95
# 2012-10-04   1.96
# 2012-10-05   1.93
# ...           ...
# 2019-12-23  27.95
# 2019-12-24  28.35
# 2019-12-26  28.73
# 2019-12-27  28.69
# 2019-12-30  27.65
#
# [1823 rows x 1 columns]

# %%
# Combine all stocks in a single DataFrame

combined_stocks = pd.concat([apple_data,google_data,tesla_data], axis = 'columns', join = 'inner')

combined_stocks
# Out:
#             Close  Close  Close
# Date
# 2014-03-27  19.20  27.85  13.82
# 2014-03-28  19.17  27.92  14.16
# 2014-03-31  19.17  27.77  13.90
# 2014-04-01  19.34  28.28  14.46
# 2014-04-02  19.38  28.27  15.35
# ...           ...    ...    ...
# 2019-12-23  71.00  67.44  27.95
# 2019-12-24  71.07  67.18  28.35
# 2019-12-26  72.48  68.02  28.73
# 2019-12-27  72.45  67.59  28.69
# 2019-12-30  72.88  66.81  27.65
#
# [1451 rows x 3 columns]

# %%
# Reorganize portfolio data by having a column per symbol

columns = ["AAPL", "GOOG", "TSLA"]
combined_stocks.columns = columns
combined_stocks
# Out:
#              AAPL   GOOG   TSLA
# Date
# 2014-03-27  19.20  27.85  13.82
# 2014-03-28  19.17  27.92  14.16
# 2014-03-31  19.17  27.77  13.90
# 2014-04-01  19.34  28.28  14.46
# 2014-04-02  19.38  28.27  15.35
# ...           ...    ...    ...
# 2019-12-23  71.00  67.44  27.95
# 2019-12-24  71.07  67.18  28.35
# 2019-12-26  72.48  68.02  28.73
# 2019-12-27  72.45  67.59  28.69
# 2019-12-30  72.88  66.81  27.65
#
# [1451 rows x 3 columns]

# %%
# Calculate daily returns

combined_stocks_daily_return = combined_stocks.pct_change()

combined_stocks_daily_return

# Drop NAs

combined_stocks_daily_return.dropna(inplace = True)

# Display sample data

combined_stocks_daily_return.sample()
# Out:
#                 AAPL    GOOG      TSLA
# Date
# 2018-01-31  0.002875  0.0055  0.024729

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights

weights = [1/3, 1/3, 1/3]

# Calculate portfolio return

portfolio_returns = combined_stocks_daily_return.dot(weights)

# Display sample data

portfolio_returns.sample()
# Out:
# Date
# 2017-04-20    0.00225
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

complete_compare_set_daily_return = pd.concat([combined,portfolio_returns],axis = 'columns',join = 'inner')
complete_compare_set_daily_return

columns = [
    'SOROS FUND MANAGEMENT LLC',
    'PAULSON & CO.INC.',
    'TIGER GLOBAL MANAGEMENT LLC',
    'BERKSHIRE HATHAWAY INC',
    'Algo 1',
    'Algo 2',
    'S&P TSX',
    'Customized',

]

complete_compare_set_daily_return.columns= columns
complete_compare_set_daily_return
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.  \
# Date
# 2015-03-03                  -0.001266          -0.004981
# 2015-03-04                   0.002230           0.003241
# 2015-03-05                   0.004016           0.004076
# 2015-03-06                  -0.007905          -0.003574
# 2015-03-09                   0.000582           0.004225
# ...                               ...                ...
# 2019-04-25                  -0.000285          -0.001291
# 2019-04-26                   0.008149           0.009162
# 2019-04-29                   0.001254           0.002719
# 2019-04-30                  -0.001295          -0.002211
# 2019-05-01                  -0.005847          -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
# ...                                 ...                     ...       ...
# 2019-04-25                    -0.005153                0.004848  0.000682
# 2019-04-26                     0.012355                0.010434  0.002981
# 2019-04-29                     0.006251                0.005223  0.005208
# 2019-04-30                    -0.000259               -0.003702 -0.002944
# 2019-05-01                    -0.007936               -0.007833  0.000094
#
#               Algo 2   S&P TSX  Customized
# Date
# 2015-03-03 -0.000949 -0.008530    0.005556
# 2015-03-04  0.002416 -0.003371    0.002835
# 2015-03-05  0.004323  0.001344   -0.007398
# 2015-03-06 -0.011460 -0.009972   -0.015098
# 2015-03-09  0.001303 -0.006555   -0.003093
# ...              ...       ...         ...
# 2019-04-25 -0.007247 -0.000628   -0.015176
# 2019-04-26  0.005256  0.002254   -0.015995
# 2019-04-29  0.002829 -0.000788    0.013420
# 2019-04-30 -0.001570 -0.001183   -0.036001
# 2019-05-01 -0.007358 -0.004703    0.004128
#
# [1029 rows x 8 columns]

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
complete_compare_set_daily_return.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# Algo 1                         0
# Algo 2                         0
# S&P TSX                        0
# Customized                     0
# dtype: int64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`

complete_compare_annual_std = complete_compare_set_daily_return.std() * np.sqrt(252)
complete_compare_annual_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.124259
# PAULSON & CO.INC.              0.110841
# TIGER GLOBAL MANAGEMENT LLC    0.172759
# BERKSHIRE HATHAWAY INC         0.203599
# Algo 1                         0.120470
# Algo 2                         0.132177
# S&P TSX                        0.111664
# Customized                     0.235791
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

complete_daily_return_rolling_21 = complete_compare_set_daily_return.rolling(window = 21).std()

# Plot rolling standard deviation

complete_daily_return_rolling_21.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation

complete_correlation = complete_compare_set_daily_return.corr()
complete_correlation

# Display the correlation matrix

sns.heatmap(complete_correlation,vmin=-1, vmax=1)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta

sp_rolling_60days_var

customized_rolling_60days_cov = complete_compare_set_daily_return['Customized'].rolling(window=60).cov(complete_compare_set_daily_return['S&P TSX'])

customized_beta_rolling_60days = customized_rolling_60days_cov/sp_rolling_60days_var

customized_beta_rolling_60days.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios

complete_annual_sharpe = complete_compare_set_daily_return.mean()*252/complete_compare_annual_std

# %%
# Visualize the sharpe ratios as a bar plot

complete_annual_sharpe.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### How does your portfolio do?
#
# My portfolio performs better than the market (S&P 500) and the whales portfolios, but Algo 1 portfolio performs better than mine!
